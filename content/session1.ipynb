# %%
import pyodide_kernel

# %%
import pandas as pd
import numpy as np
from string import ascii_uppercase as letters
from IPython.display import display

# %%
 tab = pd.read_csv("data/hypotheticalTalents.csv")

# %%
tab.head()
# Out:
#   initials  project.management  data.wrangling  data.analysis  \
# 0       CC                   0               0              0
# 1       MC                   0               0              1
# 2       SC                   0               0              0
# 3       NG                   0               0              0
# 4       RG                   0               1              1
#
#    subject.expertise  design  storytelling
# 0                  0       1             1
# 1                  1       0             0
# 2                  1       1             0
# 3                  0       0             1
# 4                  0       0             1

# %%
tab["project.management"].sum()
# Out:
# np.int64(5)
